# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load array [1,9,3,7,5] into data
data = np.array([1,9,3,7,5])

# %%
#visualize data into pyplot
plt.plot(data)
plt.ylabel('some numbers')
plt.show()
